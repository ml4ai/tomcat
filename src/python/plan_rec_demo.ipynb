# %%
from PSDG_Domain import PSDG_Domain
from sar_domain import actions, methods
from nltk import Nonterminal
from numpy import math,e
import copy

# %%
sar = PSDG_Domain(methods,actions)
next_loc = [
 'Entrance Lobby',
 'Left Hallway',
 'Security Office',
 'Left Hallway',
 'Break Room',
 'Left Hallway',
 'Executive Suite 1',
 'Left Hallway',
 'Center Hallway Middle',
 'Entrance Walkway',
 'Entrance Lobby',
 'Left Hallway',
 'Security Office',
 'Left Hallway',
 'Break Room',
 'Left Hallway',
 'Executive Suite 1',
 'Left Hallway',
 'Center Hallway Middle',
 'Right Hallway',
 'Center Hallway Top',
 'Room 101',
 'Center Hallway Top',
 'Herbalife Conference Room',
 'Center Hallway Top',
 'Left Hallway',
 'Center Hallway Top',
 'Right Hallway',
 'Room 107',
 'Right Hallway',
 'Center Hallway Top',
 'Room 101',
 'Center Hallway Top',
 'Herbalife Conference Room',
 'Room 107',
 'Herbalife Conference Room',
 'Room 107',
 'Herbalife Conference Room',
 'Room 107',
 'Herbalife Conference Room',
 'Herbalife Conference Room',
 'Room 108',
 'Room 109',
 'Center Hallway Top',
 'Room 110',
 'Right Hallway',
 'Room 111',
 'Right Hallway',
 'Room 107',
 'Computer Farm',
 'Room 107',
 'Room 107',
 'Computer Farm',
 'Right Hallway',
 'Room 109',
 'Room 108',
 'Room 107',
 'Room 108',
 'Room 109',
 'Room 110',
 'Room 110',
 'Room 110',
 'Right Hallway',
 'Room 109',
 'Room 111',
 'Right Hallway',
 'Computer Farm',
 'Left Hallway',
 'Break Room',
 'Left Hallway',
 'Center Hallway Middle',
 'Right Hallway',
 'Left Hallway',
 'Executive Suite 2',
 'Left Hallway',
 'Room 111',
 'Center Hallway Middle',
 'Room 111',
 'Center Hallway Middle',
 'Right Hallway',
 'Room 111',
 'Room 105',
 'Room 111',
 'Room 105',
 'Right Hallway',
 'Room 103',
 'Room 111',
 'Room 103',
 'Room 111',
 'Right Hallway',
 'Room 102',
 'Room 111',
 'Room 102',
 'Right Hallway',
 'Center Hallway Top',
 'Room 101',
 'Computer Farm',
 'Room 101',
 'Computer Farm',
 'Room 101',
 'Computer Farm',
 'Room 101',
 'Center Hallway Top',
 'Computer Farm',
 'Center Hallway Top',
 'Left Hallway',
 "King Chris's Office",
 "The King's Terrace"]


hallways = [
    'Entrance Walkway',
    'Entrance Lobby',
    'Left Hallway',
    'Center Hallway Middle',
    'Center Hallway Top',
    'Right Hallway',
    'Center Hallway Bottom',
    'Front Yard'
]

rooms = list(set([i for i in next_loc if not i in hallways]))
initial_state = {'time': 0, 
                 'num_of_yellow_victims_found_in_adj_room': 0, 
                 'num_of_yellow_victims_found_total': 0,
                 'num_of_green_victims_found_in_adj_room': 0,
                 'num_of_green_victims_found_total': 0,
                 'times_searched': 0,
                 'num_of_yellow_victims_found_in_current_room': 0,
                 'num_of_green_victims_found_in_current_room': 0,
                 'current_loc': 'Entrance Walkway',
                 'next_loc': next_loc,
                 'hallways': hallways,
                 'rooms': rooms,
                 "num_of_yellow_victims_triaged_in_current_room": 0,
                 "num_of_green_victims_triaged_in_current_room": 0,
                 "num_of_yellow_victims_triaged_total": 0,
                 "num_of_green_victims_triaged_total": 0,
                 "recent_search": 0
                }
sar.initialize_planning(initial_state)

# %%
q_0 = {'current_loc': 'Entrance Walkway',
   'hallways': ['Entrance Walkway',
                'Entrance Lobby',
                'Left Hallway',
                'Center Hallway Middle',
                'Center Hallway Top',
                'Right Hallway',
                'Center Hallway Bottom',
                'Front Yard'],
   'next_loc': ['Entrance Lobby',
                'Left Hallway',
                'Security Office',
                'Left Hallway',
                'Break Room',
                'Left Hallway',
                'Executive Suite 1',
                'Left Hallway',
                'Center Hallway Middle',
                'Entrance Walkway',
                'Entrance Lobby',
                'Left Hallway',
                'Security Office',
                'Left Hallway',
                'Break Room',
                'Left Hallway',
                'Executive Suite 1',
                'Left Hallway',
                'Center Hallway Middle',
                'Right Hallway',
                'Center Hallway Top',
                'Room 101',
                'Center Hallway Top',
                'Herbalife Conference Room',
                'Center Hallway Top',
                'Left Hallway',
                'Center Hallway Top',
                'Right Hallway',
                'Room 107',
                'Right Hallway',
                'Center Hallway Top',
                'Room 101',
                'Center Hallway Top',
                'Herbalife Conference Room',
                'Room 107',
                'Herbalife Conference Room',
                'Room 107',
                'Herbalife Conference Room',
                'Room 107',
                'Herbalife Conference Room',
                'Herbalife Conference Room',
                'Room 108',
                'Room 109',
                'Center Hallway Top',
                'Room 110',
                'Right Hallway',
                'Room 111',
                'Right Hallway',
                'Room 107',
                'Computer Farm',
                'Room 107',
                'Room 107',
                'Computer Farm',
                'Right Hallway',
                'Room 109',
                'Room 108',
                'Room 107',
                'Room 108',
                'Room 109',
                'Room 110',
                'Room 110',
                'Room 110',
                'Right Hallway',
                'Room 109',
                'Room 111',
                'Right Hallway',
                'Computer Farm',
                'Left Hallway',
                'Break Room',
                'Left Hallway',
                'Center Hallway Middle',
                'Right Hallway',
                'Left Hallway',
                'Executive Suite 2',
                'Left Hallway',
                'Room 111',
                'Center Hallway Middle',
                'Room 111',
                'Center Hallway Middle',
                'Right Hallway',
                'Room 111',
                'Room 105',
                'Room 111',
                'Room 105',
                'Right Hallway',
                'Room 103',
                'Room 111',
                'Room 103',
                'Room 111',
                'Right Hallway',
                'Room 102',
                'Room 111',
                'Room 102',
                'Right Hallway',
                'Center Hallway Top',
                'Room 101',
                'Computer Farm',
                'Room 101',
                'Computer Farm',
                'Room 101',
                'Computer Farm',
                'Room 101',
                'Center Hallway Top',
                'Computer Farm',
                'Center Hallway Top',
                'Left Hallway',
                "King Chris's Office",
                "The King's Terrace"],
   'num_of_green_victims_found_in_adj_room': 0,
   'num_of_green_victims_found_in_current_room': 0,
   'num_of_green_victims_found_total': 0,
   'num_of_green_victims_triaged_in_current_room': 0,
   'num_of_green_victims_triaged_total': 0,
   'num_of_yellow_victims_found_in_adj_room': 0,
   'num_of_yellow_victims_found_in_current_room': 0,
   'num_of_yellow_victims_found_total': 0,
   'num_of_yellow_victims_triaged_in_current_room': 0,
   'num_of_yellow_victims_triaged_total': 0,
   'recent_search': 0,
   'rooms': ["King Chris's Office",
             "The King's Terrace",
             'Room 111',
             'Room 105',
             'Security Office',
             'Room 103',
             'Room 110',
             'Herbalife Conference Room',
             'Room 107',
             'Room 101',
             'Executive Suite 1',
             'Break Room',
             'Room 108',
             'Computer Farm',
             'Room 102',
             'Room 109',
             'Executive Suite 2'],
   'time': 0,
   'times_searched': 0}

# %%
q_1 = {'current_loc': 'Entrance Walkway',
   'hallways': ['Entrance Walkway',
                'Entrance Lobby',
                'Left Hallway',
                'Center Hallway Middle',
                'Center Hallway Top',
                'Right Hallway',
                'Center Hallway Bottom',
                'Front Yard'],
   'next_loc': ['Entrance Lobby',
                'Left Hallway',
                'Security Office',
                'Left Hallway',
                'Break Room',
                'Left Hallway',
                'Executive Suite 1',
                'Left Hallway',
                'Center Hallway Middle',
                'Entrance Walkway',
                'Entrance Lobby',
                'Left Hallway',
                'Security Office',
                'Left Hallway',
                'Break Room',
                'Left Hallway',
                'Executive Suite 1',
                'Left Hallway',
                'Center Hallway Middle',
                'Right Hallway',
                'Center Hallway Top',
                'Room 101',
                'Center Hallway Top',
                'Herbalife Conference Room',
                'Center Hallway Top',
                'Left Hallway',
                'Center Hallway Top',
                'Right Hallway',
                'Room 107',
                'Right Hallway',
                'Center Hallway Top',
                'Room 101',
                'Center Hallway Top',
                'Herbalife Conference Room',
                'Room 107',
                'Herbalife Conference Room',
                'Room 107',
                'Herbalife Conference Room',
                'Room 107',
                'Herbalife Conference Room',
                'Herbalife Conference Room',
                'Room 108',
                'Room 109',
                'Center Hallway Top',
                'Room 110',
                'Right Hallway',
                'Room 111',
                'Right Hallway',
                'Room 107',
                'Computer Farm',
                'Room 107',
                'Room 107',
                'Computer Farm',
                'Right Hallway',
                'Room 109',
                'Room 108',
                'Room 107',
                'Room 108',
                'Room 109',
                'Room 110',
                'Room 110',
                'Room 110',
                'Right Hallway',
                'Room 109',
                'Room 111',
                'Right Hallway',
                'Computer Farm',
                'Left Hallway',
                'Break Room',
                'Left Hallway',
                'Center Hallway Middle',
                'Right Hallway',
                'Left Hallway',
                'Executive Suite 2',
                'Left Hallway',
                'Room 111',
                'Center Hallway Middle',
                'Room 111',
                'Center Hallway Middle',
                'Right Hallway',
                'Room 111',
                'Room 105',
                'Room 111',
                'Room 105',
                'Right Hallway',
                'Room 103',
                'Room 111',
                'Room 103',
                'Room 111',
                'Right Hallway',
                'Room 102',
                'Room 111',
                'Room 102',
                'Right Hallway',
                'Center Hallway Top',
                'Room 101',
                'Computer Farm',
                'Room 101',
                'Computer Farm',
                'Room 101',
                'Computer Farm',
                'Room 101',
                'Center Hallway Top',
                'Computer Farm',
                'Center Hallway Top',
                'Left Hallway',
                "King Chris's Office",
                "The King's Terrace"],
   'num_of_green_victims_found_in_adj_room': 0,
   'num_of_green_victims_found_in_current_room': 0,
   'num_of_green_victims_found_total': 0,
   'num_of_green_victims_triaged_in_current_room': 0,
   'num_of_green_victims_triaged_total': 0,
   'num_of_yellow_victims_found_in_adj_room': 0,
   'num_of_yellow_victims_found_in_current_room': 0,
   'num_of_yellow_victims_found_total': 0,
   'num_of_yellow_victims_triaged_in_current_room': 0,
   'num_of_yellow_victims_triaged_total': 0,
   'recent_search': 1,
   'rooms': ["King Chris's Office",
             "The King's Terrace",
             'Room 111',
             'Room 105',
             'Security Office',
             'Room 103',
             'Room 110',
             'Herbalife Conference Room',
             'Room 107',
             'Room 101',
             'Executive Suite 1',
             'Break Room',
             'Room 108',
             'Computer Farm',
             'Room 102',
             'Room 109',
             'Executive Suite 2'],
   'time': 7,
   'times_searched': 1}

# %%
def initialize_B_state(grammar,d):
    B_s = {'Q': 0.0, 'N': {}, "P": {}, "Sig": {}, "T|N": {}, "T": {}}
    
    
    for i in range(1,d+1):
        B_s["N"][i] = {}
        B_s["T|N"][i] = {}
        for j in grammar.nonterminals:
            B_s["N"][i][j] = 0.0
            B_s["T|N"][i][j] = 0.0
            
        B_s["T|N"][i]['nil'] = 1.0
        B_s["N"][i]['nil'] = 0.0
        
        B_s["P"][i] = {}
        for a in grammar.productions():
            for l in range(1,len(a.rhs()) + 1):
                B_s["P"][i][(a.__str__(omit_probs = True), l)] = 0.0
        
        B_s["T"][i] = 0.0
        
    for e in grammar.terminals:
        B_s["Sig"][e] = 0.0
        
    return B_s

# %%
def initialize_E_state(grammar,d,t):
    E_s = {"t": t - 1,"pi_2": {}, "p_Q": {}, "p_T_sig_T": {}, "p_T_sig": {}}
    
    for i in range(1,d+1):
        E_s["pi_2"][i] = {}
        for j in grammar.nonterminals:
            E_s["pi_2"][i][j] = {'T': 0.0, '-T': 0.0}
        
        E_s["pi_2"][i]['nil'] = {'T': 0.0, '-T': 0.0}
        
        E_s["p_Q"][i] = 0.0
        
        E_s["p_T_sig_T"][i] = 0.0
        
        E_s["p_T_sig"][i] = 0.0
        
    return E_s

# %%
def compute_T(grammar,B,d,t):
    for l in range(d - 1,0,-1):
        pos_sym = (x for x in B[t]["N"][l] if B[t]["N"][l][x] > 0.0)
        for sym in pos_sym:
            for a in grammar.productions(lhs=sym):
                if a.rhs()[-1] != sym:
                    if isinstance(a.rhs()[-1],Nonterminal):
                        B[t]['T|N'][l][sym] += (
                            (B[t]["P"][l][(a.__str__(omit_probs = True), len(a.rhs()))]
                                        *B[t]['T|N'][l+1][a.rhs()[-1]])/B[t]["N"][l][sym]
                        )
                    else:
                        B[t]['T|N'][l][sym] += (
                                B[t]["P"][l][(a.__str__(omit_probs = True), len(a.rhs()))]/B[t]["N"][l][sym]
                        )
            
            B[t]['T'][l] += B[t]['T|N'][l][sym]*B[t]["N"][l][sym]
    return B

# %%
def initialize_belief_state(grammar,d,q):
    grammar.update_prods(q)
    B = {1: initialize_B_state(grammar,d)}
    B[1]['Q'] = 1.0
    B[1]['N'][1][grammar.start()] = 1.0
    for l in range(2,d + 1):
        pos_sym = (x for x in B[1]["N"][l - 1] if B[1]["N"][l - 1][x] > 0.0)
        for sym in pos_sym:
            for a in grammar.productions(lhs=sym):
                B[1]["P"][l-1][(a.__str__(omit_probs = True), 1)] += B[1]["N"][l-1][sym]*a.prob()
                if isinstance(a.rhs()[0],Nonterminal):
                    B[1]["N"][l][a.rhs()[0]] += B[1]["P"][l-1][(a.__str__(omit_probs = True),1)]
                else:
                    B[1]["Sig"][a.rhs()[0]] += B[1]["P"][l-1][(a.__str__(omit_probs = True),1)]
    
        p_sum = 0.0
        for i in grammar.nonterminals:
            p_sum += B[1]['N'][l][i]
        B[1]['N'][l]['nil'] = 1 - p_sum
    B = compute_T(grammar,B,d,1)
    return B

# %%
def explanation_phase(grammar,actions,B,d,q_0,q_1,t):
    
    E = initialize_E_state(grammar,d,t)
    if not(t in B):
        B[t] = initialize_B_state(grammar,d)
        
    for i in actions:
        B[t]["Q"] += i.state_trans_prob(q_0,q_1)*B[t-1]["Sig"][i.__name__]
    
    max_m = 0
    for a in grammar.productions():
        if len(a.rhs()) >= max_m:
            max_m = len(a.rhs())
            
    for l in range(d - 1,0,-1):
        pos_sym = (x for x in B[t-1]["N"][l] if B[t-1]["N"][l][x] > 0.0)
        for sym in pos_sym:
            for a in grammar.productions(lhs=sym):
                if a.rhs()[-1] != sym:
                    if isinstance(a.rhs()[-1],Nonterminal):
                        E['pi_2'][l][sym]['T'] += (
                            B[t-1]["P"][l][(a.__str__(omit_probs = True), len(a.rhs()))]
                            *E['pi_2'][l+1][a.rhs()[-1]]['T']
                        )
                        
                        E['pi_2'][l][sym]['-T'] += (
                            B[t-1]["P"][l][(a.__str__(omit_probs = True), len(a.rhs()))]
                            *E['pi_2'][l+1][a.rhs()[-1]]['-T']
                        )
                    else:
                        act = next((x for x in actions if x.__name__ == a.rhs()[-1]), None)
                        E['pi_2'][l][sym]['T'] += (
                            B[t-1]["P"][l][(a.__str__(omit_probs = True), len(a.rhs()))]
                            *act.state_trans_prob(q_0,q_1)
                        )
                        
                for b in range(1,len(a.rhs())):
                    if isinstance(a.rhs()[b-1],Nonterminal):
                        E['pi_2'][l][sym]['-T'] += (
                            B[t-1]["P"][l][(a.__str__(omit_probs = True), b)]
                            *E['pi_2'][l+1][a.rhs()[b-1]]['-T']
                        )
                        
                        E['pi_2'][l][sym]['-T'] += (
                            B[t-1]["P"][l][(a.__str__(omit_probs = True), b)]
                            *E['pi_2'][l+1][a.rhs()[b-1]]['T']
                        )
                    else:
                        act = next((x for x in actions if x.__name__ == a.rhs()[b-1]), None)
                        E['pi_2'][l][sym]['-T'] += (
                            B[t-1]["P"][l][(a.__str__(omit_probs = True), b)]
                            *act.state_trans_prob(q_0,q_1)
                        )
            
            E['pi_2'][l][sym]['T'] /= B[t-1]["N"][l][sym]  
            E['pi_2'][l][sym]['-T'] /= B[t-1]["N"][l][sym]
            
            
            E['p_Q'][l] += B[t-1]["N"][l][sym]*E['pi_2'][l][sym]['T']
    
        for k in range(1,l + 1):
            for a in grammar.productions():
                for i,b in enumerate(a.rhs()):
                    if not(isinstance(b,Nonterminal)):
                        act = next((x for x in actions if x.__name__ == b), None)
                        E['p_Q'][l] += (
                            B[t-1]["P"][k][(a.__str__(omit_probs = True), i+1)]
                            *act.state_trans_prob(q_0,q_1)
                        )
        
        for m in range(1,max_m + 1):
            for a in grammar.productions():
                if len(a.rhs()) == m:
                    if not(isinstance(a.rhs()[-1], Nonterminal)):
                        act = next((x for x in actions if x.__name__ == a.rhs()[-1]), None)
                        E['p_T_sig_T'][l] += (
                            B[t-1]["P"][l][(a.__str__(omit_probs = True), m)]
                            *act.state_trans_prob(q_0,q_1)
                        )
                    else:
                        E['p_T_sig_T'][l] += (
                            B[t-1]["P"][l][(a.__str__(omit_probs = True), m)]
                            *E['pi_2'][l+1][a.rhs()[-1]]['T']
                        )
        if l < (d - 1):
            E['p_T_sig_T'][l] /= E['p_Q'][l+1]
            E['p_T_sig'][l] = E['p_T_sig_T'][l]
        else:
            E['p_T_sig_T'][l] /= B[t]["Q"]
        
        E['p_T_sig_T'][l] *= B[t-1]["T"][l + 1]
        E['p_T_sig_T'][l] += B[t-1]["N"][l]['nil']
    
    return B, E

# %%
B = initialize_belief_state(sar.psdg,4,initial_state)

# %%
B

# %%
(B, E) = explanation_phase(sar.psdg,actions,B,4,q_0,q_1,2)

# %%
B

# %%
E

# %%
def sym_exp(B,E,d):
    N_E = {'t': E['t'], 'N':{}}
    for l in range(1,d+1):
        N_E["N"][l] = {}
        for sym in B[E['t']]['N'][l]:
            N_E["N"][l][sym] = (
                B[E['t']]['N'][l][sym]
                *(
                   E['pi_2'][l][sym]['T']
                   +E['pi_2'][l][sym]['-T']
                )
                /B[E['t']+1]['Q']
            )
    return N_E

# %%
N_E = sym_exp(B,E,4)

# %%
N_E
